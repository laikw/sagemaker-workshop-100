# %% [markdown]
# # Direct Marketing with Amazon SageMaker Autopilot
# ---
#
# ---

# %% [markdown]
# ## Contents
#
# 1. [Introduction](#Introduction)
# 1. [Prerequisites](#Prerequisites)
# 1. [Downloading the dataset](#Downloading)
# 1. [Upload the dataset to Amazon S3](#Uploading)
# 1. [Setting up the SageMaker Autopilot Job](#Settingup)
# 1. [Launching the SageMaker Autopilot Job](#Launching)
# 1. [Tracking Sagemaker Autopilot Job Progress](#Tracking)
# 1. [Results](#Results)
# 1. [Cleanup](#Cleanup)

# %% [markdown]
# ## Introduction
#
# Amazon SageMaker Autopilot is an automated machine learning (commonly referred to as AutoML) solution for tabular datasets. You can use SageMaker Autopilot in different ways: on autopilot (hence the name) or with human guidance, without code through SageMaker Studio, or using the AWS SDKs. This notebook, as a first glimpse, will use the AWS SDKs to simply create and deploy a machine learning model.
#
# A typical introductory task in machine learning (the "Hello World" equivalent) is one that uses a dataset to predict whether a customer will enroll for a term deposit at a bank, after one or more phone calls. For more information about the task and the dataset used, see [Bank Marketing Data Set](https://archive.ics.uci.edu/ml/datasets/bank+marketing).
#
# Direct marketing, through mail, email, phone, etc., is a common tactic to acquire customers.  Because resources and a customer's attention are limited, the goal is to only target the subset of prospects who are likely to engage with a specific offer.  Predicting those potential customers based on readily available information like demographics, past interactions, and environmental factors is a common machine learning problem. You can imagine that this task would readily translate to marketing lead prioritization in your own organization.
#
# This notebook demonstrates how you can use Autopilot on this dataset to get the most accurate ML pipeline through exploring a number of potential options, or "candidates". Each candidate generated by Autopilot consists of two steps. The first step performs automated feature engineering on the dataset and the second step trains and tunes an algorithm to produce a model. When you deploy this model, it follows similar steps. Feature engineering followed by inference, to decide whether the lead is worth pursuing or not. The notebook contains instructions on how to train the model as well as to deploy the model to perform batch predictions on a set of leads. Where it is possible, use the Amazon SageMaker Python SDK, a high level SDK, to simplify the way you interact with Amazon SageMaker.
#
# Other examples demonstrate how to customize models in various ways. For instance, models deployed to devices typically have memory constraints that need to be satisfied as well as accuracy. Other use cases have real-time deployment requirements and latency constraints. For now, keep it simple.

# %% [markdown]
# ## Prerequisites
#
# Before you start the tasks in this tutorial, do the following:
#
# - The Amazon Simple Storage Service (Amazon S3) bucket and prefix that you want to use for training and model data. This should be within the same Region as Amazon SageMaker training. The code below will create, or if it exists, use, the default bucket.
# - The IAM role to give Autopilot access to your data. See the Amazon SageMaker documentation for more information on IAM roles: https://docs.aws.amazon.com/sagemaker/latest/dg/security-iam.html

# %%
# cell 01
import sagemaker
import boto3
from sagemaker import get_execution_role

region = boto3.Session().region_name

session = sagemaker.Session()
bucket = session.default_bucket()
prefix = 'sagemaker/autopilot-dm'

role = get_execution_role()

sm = boto3.Session().client(service_name='sagemaker',region_name=region)

# %% [markdown]
# ## Downloading the dataset<a name="Downloading"></a>
# Download the [direct marketing dataset](!wget -N https://sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com/autopilot/direct_marketing/bank-additional.zip) from the sample data s3 bucket.
#
# \[Moro et al., 2014\] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014

# %%
# cell 02
# !wget -N https://sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com/autopilot/direct_marketing/bank-additional.zip
# !conda install -y -c conda-forge unzip
# !unzip -o bank-additional.zip

local_data_path = './bank-additional/bank-additional-full.csv'
# Out:
# --2022-01-13 03:38:11--  https://sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com/autopilot/direct_marketing/bank-additional.zip
# Resolving sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com (sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com)... 52.218.228.241
# Connecting to sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com (sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com)|52.218.228.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 432828 (423K) [application/zip]
# Saving to: ‘bank-additional.zip’
#
# bank-additional.zip 100%[===================>] 422.68K   629KB/s    in 0.7s
#
# 2022-01-13 03:38:13 (629 KB/s) - ‘bank-additional.zip’ saved [432828/432828]
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - unzip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1m             |       h7f8727e_0         2.5 MB
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1l-h7f8727e_0 --> 1.1.1m-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1m       | 2.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Archive:  bank-additional.zip
#    creating: bank-additional/
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: bank-additional/bank-additional-full.csv

# %% [markdown]
# ## Upload the dataset to Amazon S3<a name="Uploading"></a>
#
# Before you run Autopilot on the dataset, first perform a check of the dataset to make sure that it has no obvious errors. The Autopilot process can take long time, and it's generally a good practice to inspect the dataset before you start a job. This particular dataset is small, so you can inspect it in the notebook instance itself. If you have a larger dataset that will not fit in a notebook instance memory, inspect the dataset offline using a big data analytics tool like Apache Spark. [Deequ](https://github.com/awslabs/deequ) is a library built on top of Apache Spark that can be helpful for performing checks on large datasets. Autopilot is capable of handling datasets up to 5 GB.

# %% [markdown]
# Read the data into a Pandas data frame and take a look.

# %%
# cell 03
import pandas as pd

data = pd.read_csv(local_data_path)
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 10)         # Keep the output on one page
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# 1      telephone   may         mon       149         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994          -36.4      4.857
# 1      nonexistent           1.1          93.994          -36.4      4.857
# 2      nonexistent           1.1          93.994          -36.4      4.857
# 3      nonexistent           1.1          93.994          -36.4      4.857
# 4      nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent          -1.1          94.767          -50.8      1.028
# 41184  nonexistent          -1.1          94.767          -50.8      1.028
# 41185  nonexistent          -1.1          94.767          -50.8      1.028
# 41186  nonexistent          -1.1          94.767          -50.8      1.028
# 41187      failure          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# Note that there are 20 features to help predict the target column 'y'.
#
# Amazon SageMaker Autopilot takes care of preprocessing your data for you. You do not need to perform conventional data preprocssing techniques such as handling missing values, converting categorical features to numeric features, scaling data, and handling more complicated data types.
#
# Moreover, splitting the dataset into training and validation splits is not necessary. Autopilot takes care of this for you. You may, however, want to split out a test set. That's next, although you use it for batch inference at the end instead of testing the model.

# %% [markdown]
# ### Reserve some data for calling batch inference on the model
#
# Divide the data into training and testing splits. The training split is used by SageMaker Autopilot. The testing split is reserved to perform inference using the suggested model.

# %%
# cell 04
train_data = data.sample(frac=0.8,random_state=200)

test_data = data.drop(train_data.index)

test_data_no_target = test_data.drop(columns=['y'])

# %% [markdown]
# ### Upload the dataset to Amazon S3
# Copy the file to Amazon Simple Storage Service (Amazon S3) in a .csv format for Amazon SageMaker training to use.

# %%
# cell 05
train_file = 'train_data.csv';
train_data.to_csv(train_file, index=False, header=True)
train_data_s3_path = session.upload_data(path=train_file, key_prefix=prefix + "/train")
print('Train data uploaded to: ' + train_data_s3_path)

test_file = 'test_data.csv';
test_data_no_target.to_csv(test_file, index=False, header=False)
test_data_s3_path = session.upload_data(path=test_file, key_prefix=prefix + "/test")
print('Test data uploaded to: ' + test_data_s3_path)
# Out:
# Train data uploaded to: s3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/train/train_data.csv
# Test data uploaded to: s3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/test/test_data.csv

# %% [markdown]
# ## Setting up the SageMaker Autopilot Job<a name="Settingup"></a>
#
# After uploading the dataset to Amazon S3, you can invoke Autopilot to find the best ML pipeline to train a model on this dataset.
#
# The required inputs for invoking a Autopilot job are:
# * Amazon S3 location for input dataset and for all output artifacts
# * Name of the column of the dataset you want to predict (`y` in this case)
# * An IAM role
#
# Currently Autopilot supports only tabular datasets in CSV format. Either all files should have a header row, or the first file of the dataset, when sorted in alphabetical/lexical order, is expected to have a header row.

# %%
# cell 06
input_data_config = [{
      'DataSource': {
        'S3DataSource': {
          'S3DataType': 'S3Prefix',
          'S3Uri': 's3://{}/{}/train'.format(bucket,prefix)
        }
      },
      'TargetAttributeName': 'y'
    }
  ]

output_data_config = {
    'S3OutputPath': 's3://{}/{}/output'.format(bucket,prefix)
  }

autoMLJobConfig={
        'CompletionCriteria': {
            'MaxCandidates': 5
        }
}

autoMLJobObjective = {
      "MetricName": "Accuracy"
}

# %% [markdown]
# You can also specify the type of problem you want to solve with your dataset (`Regression, MulticlassClassification, BinaryClassification`). In case you are not sure, SageMaker Autopilot will infer the problem type based on statistics of the target column (the column you want to predict).
#
# You have the option to limit the running time of a SageMaker Autopilot job by providing either the maximum number of pipeline evaluations or candidates (one pipeline evaluation is called a `Candidate` because it generates a candidate model) or providing the total time allocated for the overall Autopilot job. Under default settings, this job takes about four hours to run. This varies between runs because of the nature of the exploratory process Autopilot uses to find optimal training parameters.

# %% [markdown]
# ## Launching the SageMaker Autopilot Job<a name="Launching"></a>
#
# You can now launch the Autopilot job by calling the `create_auto_ml_job` API. https://docs.aws.amazon.com/cli/latest/reference/sagemaker/create-auto-ml-job.html

# %%
# cell 07
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())

auto_ml_job_name = 'automl-banking-' + timestamp_suffix
print('AutoMLJobName: ' + auto_ml_job_name)

sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      AutoMLJobConfig=autoMLJobConfig,
                      AutoMLJobObjective=autoMLJobObjective,
                      ProblemType="BinaryClassification",
                      RoleArn=role)
# Out:
# AutoMLJobName: automl-banking-13-03-39-12
# {'AutoMLJobArn': 'arn:aws:sagemaker:ap-southeast-1:138604873012:automl-job/automl-banking-13-03-39-12',
#  'ResponseMetadata': {'RequestId': '635e8d76-36ac-4992-a755-8c0c5c9133b2',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '635e8d76-36ac-4992-a755-8c0c5c9133b2',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '102',
#    'date': 'Thu, 13 Jan 2022 03:39:13 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Tracking SageMaker Autopilot job progress<a name="Tracking"></a>
# SageMaker Autopilot job consists of the following high-level steps :
# * Analyzing Data, where the dataset is analyzed and Autopilot comes up with a list of ML pipelines that should be tried out on the dataset. The dataset is also split into train and validation sets.
# * Feature Engineering, where Autopilot performs feature transformation on individual features of the dataset as well as at an aggregate level.
# * Model Tuning, where the top performing pipeline is selected along with the optimal hyperparameters for the training algorithm (the last stage of the pipeline).

# %%
# cell 08
print ('JobStatus - Secondary Status')
print('------------------------------')


describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
print (describe_response['AutoMLJobStatus'] + " - " + describe_response['AutoMLJobSecondaryStatus'])
job_run_status = describe_response['AutoMLJobStatus']
    
while job_run_status not in ('Failed', 'Completed', 'Stopped'):
    describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    job_run_status = describe_response['AutoMLJobStatus']
    
    print (describe_response['AutoMLJobStatus'] + " - " + describe_response['AutoMLJobSecondaryStatus'])
    sleep(30)
# Out:
# JobStatus - Secondary Status
# ------------------------------
# InProgress - Starting
# InProgress - Starting
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# Completed - Completed

# %% [markdown]
# ## Results
#
# Now use the describe_auto_ml_job API to look up the best candidate selected by the SageMaker Autopilot job.

# %%
# cell 09
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['BestCandidate']
best_candidate_name = best_candidate['CandidateName']
print(best_candidate)
print('\n')
print("CandidateName: " + best_candidate_name)
print("FinalAutoMLJobObjectiveMetricName: " + best_candidate['FinalAutoMLJobObjectiveMetric']['MetricName'])
print("FinalAutoMLJobObjectiveMetricValue: " + str(best_candidate['FinalAutoMLJobObjectiveMetric']['Value']))
# Out:
# {'CandidateName': 'automl-banking-13-03-39-12PjvDdi-001-90f87382', 'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:accuracy', 'Value': 0.9089099764823914}, 'ObjectiveStatus': 'Succeeded', 'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob', 'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-1:138604873012:processing-job/automl-banking-13-03-39-12-db-1-c5ff2138f1c3424b8957ea49f3ed944', 'CandidateStepName': 'automl-banking-13-03-39-12-db-1-c5ff2138f1c3424b8957ea49f3ed944'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-1:138604873012:training-job/automl-banking-13-03-39-12-dpp3-1-34d68a88b2634f1e927ea2169afce', 'CandidateStepName': 'automl-banking-13-03-39-12-dpp3-1-34d68a88b2634f1e927ea2169afce'}, {'CandidateStepType': 'AWS::SageMaker::TransformJob', 'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-1:138604873012:transform-job/automl-banking-13-03-39-12-dpp3-csv-1-1deea32ff6a546e0b4c403bfd', 'CandidateStepName': 'automl-banking-13-03-39-12-dpp3-csv-1-1deea32ff6a546e0b4c403bfd'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:ap-southeast-1:138604873012:training-job/automl-banking-13-03-39-12pjvddi-001-90f87382', 'CandidateStepName': 'automl-banking-13-03-39-12PjvDdi-001-90f87382'}], 'CandidateStatus': 'Completed', 'InferenceContainers': [{'Image': '121021644041.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-sklearn-automl:2.4-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/data-processor-models/automl-banking-13-03-39-12-dpp3-1-34d68a88b2634f1e927ea2169afce/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}, {'Image': '121021644041.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-xgboost:1.2-2-cpu-py3', 'ModelDataUrl': 's3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/tuning/automl-ban-dpp3-xgb/automl-banking-13-03-39-12PjvDdi-001-90f87382/output/model.tar.gz', 'Environment': {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}}, {'Image': '121021644041.dkr.ecr.ap-southeast-1.amazonaws.com/sagemaker-sklearn-automl:2.4-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/data-processor-models/automl-banking-13-03-39-12-dpp3-1-34d68a88b2634f1e927ea2169afce/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_INPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}], 'CreationTime': datetime.datetime(2022, 1, 13, 4, 1, 1, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2022, 1, 13, 4, 4, 31, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2022, 1, 13, 4, 13, 44, 559000, tzinfo=tzlocal()), 'CandidateProperties': {'CandidateArtifactLocations': {'Explainability': 's3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output'}, 'CandidateMetrics': [{'MetricName': 'F1', 'Value': 0.4146600067615509, 'Set': 'Validation'}, {'MetricName': 'AUC', 'Value': 0.9366999864578247, 'Set': 'Validation'}, {'MetricName': 'Accuracy', 'Value': 0.9089099764823914, 'Set': 'Validation'}]}}
#
#
# CandidateName: automl-banking-13-03-39-12PjvDdi-001-90f87382
# FinalAutoMLJobObjectiveMetricName: validation:accuracy
# FinalAutoMLJobObjectiveMetricValue: 0.9089099764823914

# %% [markdown]
# ### Perform batch inference using the best candidate
#
# Now that you have successfully completed the SageMaker Autopilot job on the dataset, create a model from any of the candidates by using [Inference Pipelines](https://docs.aws.amazon.com/sagemaker/latest/dg/inference-pipelines.html).

# %%
# cell 10
model_name = 'automl-banking-model-' + timestamp_suffix

model = sm.create_model(Containers=best_candidate['InferenceContainers'],
                            ModelName=model_name,
                            ExecutionRoleArn=role)

print('Model ARN corresponding to the best candidate is : {}'.format(model['ModelArn']))
# Out:
# Model ARN corresponding to the best candidate is : arn:aws:sagemaker:ap-southeast-1:138604873012:model/automl-banking-model-13-03-39-12

# %% [markdown]
# You can use batch inference by using Amazon SageMaker batch transform. The same model can also be deployed to perform online inference using Amazon SageMaker hosting.

# %%
# cell 11
transform_job_name = 'automl-banking-transform-' + timestamp_suffix

transform_input = {
        'DataSource': {
            'S3DataSource': {
                'S3DataType': 'S3Prefix',
                'S3Uri': test_data_s3_path
            }
        },
        'ContentType': 'text/csv',
        'CompressionType': 'None',
        'SplitType': 'Line'
    }

transform_output = {
        'S3OutputPath': 's3://{}/{}/inference-results'.format(bucket,prefix),
    }

transform_resources = {
        'InstanceType': 'ml.m5.4xlarge',
        'InstanceCount': 1
    }

sm.create_transform_job(TransformJobName = transform_job_name,
                        ModelName = model_name,
                        TransformInput = transform_input,
                        TransformOutput = transform_output,
                        TransformResources = transform_resources
)
# Out:
# {'TransformJobArn': 'arn:aws:sagemaker:ap-southeast-1:138604873012:transform-job/automl-banking-transform-13-03-39-12',
#  'ResponseMetadata': {'RequestId': 'a976890c-d9e7-4381-a325-6ffa1071fe6c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'a976890c-d9e7-4381-a325-6ffa1071fe6c',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '118',
#    'date': 'Thu, 13 Jan 2022 04:24:53 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# Watch the transform job for completion.

# %%
# cell 12
print ('JobStatus')
print('----------')


describe_response = sm.describe_transform_job(TransformJobName = transform_job_name)
job_run_status = describe_response['TransformJobStatus']
print (job_run_status)

while job_run_status not in ('Failed', 'Completed', 'Stopped'):
    describe_response = sm.describe_transform_job(TransformJobName = transform_job_name)
    job_run_status = describe_response['TransformJobStatus']
    print (job_run_status)
    sleep(30)
# Out:
# JobStatus
# ----------
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# Completed

# %% [markdown]
# Now let's view the results of the transform job:

# %%
# cell 13
s3_output_key = '{}/inference-results/test_data.csv.out'.format(prefix);
local_inference_results_path = 'inference_results.csv'

s3 = boto3.resource('s3')
inference_results_bucket = s3.Bucket(session.default_bucket())

inference_results_bucket.download_file(s3_output_key, local_inference_results_path);

data = pd.read_csv(local_inference_results_path, sep=';')
pd.set_option('display.max_rows', 10)         # Keep the output on one page
data
# Out:
#       no
# 0     no
# 1     no
# 2     no
# 3     no
# 4     no
# ...   ..
# 8232  no
# 8233  no
# 8234  no
# 8235  no
# 8236  no
#
# [8237 rows x 1 columns]

# %% [markdown]
# ### View other candidates explored by SageMaker Autopilot
# You can view all the candidates (pipeline evaluations with different hyperparameter combinations) that were explored by SageMaker Autopilot and sort them by their final performance metric.

# %%
# cell 14
candidates = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name, SortBy='FinalObjectiveMetricValue')['Candidates']
index = 1
for candidate in candidates:
  print (str(index) + "  " + candidate['CandidateName'] + "  " + str(candidate['FinalAutoMLJobObjectiveMetric']['Value']))
  index += 1
# Out:
# 1  automl-banking-13-03-39-12PjvDdi-001-90f87382  0.9089099764823914
# 2  automl-banking-13-03-39-12PjvDdi-002-91ec2a21  0.9018999934196472
# 3  automl-banking-13-03-39-12PjvDdi-003-007a130e  0.8978400230407715
# 4  automl-banking-13-03-39-12PjvDdi-004-e5b9298d  0.8919922709465027
# 5  automl-banking-13-03-39-12PjvDdi-005-43ecd58b  0.858240008354187

# %% [markdown]
# ### Candidate Generation Notebook
#
# Sagemaker AutoPilot also auto-generates a Candidate Definitions notebook. This notebook can be used to interactively step through the various steps taken by the Sagemaker Autopilot to arrive at the best candidate. This notebook can also be used to override various runtime parameters like parallelism, hardware used, algorithms explored, feature extraction scripts and more.
#
# The notebook can be downloaded from the following Amazon S3 location:

# %%
# cell 15
sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
# Out:
# 's3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb'

# %% [markdown]
# ### Data Exploration Notebook
# Sagemaker Autopilot also auto-generates a Data Exploration notebook, which can be downloaded from the following Amazon S3 location:

# %%
# cell 16
sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['AutoMLJobArtifacts']['DataExplorationNotebookLocation']
# Out:
# 's3://sagemaker-ap-southeast-1-138604873012/sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'

# %% [markdown]
# ## Cleanup
#
# The Autopilot job creates many underlying artifacts such as dataset splits, preprocessing scripts, or preprocessed data, etc. This code, when un-commented, deletes them. This operation deletes all the generated models and the auto-generated notebooks as well.

# %%
# cell 17
s3 = boto3.resource('s3')
bucket = s3.Bucket(bucket)

job_outputs_prefix = '{}/output/{}'.format(prefix,auto_ml_job_name)
bucket.objects.filter(Prefix=job_outputs_prefix).delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '8FV7W2QD878RDNCQ',
#    'HostId': '/qt1MJbgFIJ10k9VZqjJeb/ZbgqKhF3HtYjyVFGN+C9zArKza1v7lQVsrM2+UDfAkqRQJj1Uw/E=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': '/qt1MJbgFIJ10k9VZqjJeb/ZbgqKhF3HtYjyVFGN+C9zArKza1v7lQVsrM2+UDfAkqRQJj1Uw/E=',
#     'x-amz-request-id': '8FV7W2QD878RDNCQ',
#     'date': 'Thu, 13 Jan 2022 04:55:59 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_17.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/candidate_data_processors/dpp4.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/interactive_runner.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_8.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_48.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_9.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/explanations_shap/out.csv/_SUCCESS'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/report.html'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/analysis.json'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_41.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_17.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_69.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_9.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_31.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_12.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/MANIFEST.in'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/candidate_data_processors/trainer.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/local_candidate.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_7.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_66.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/README.md'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_9.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_4.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_61.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_63.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/__init__.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_60.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_6.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/report.pdf'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_13.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/candidate_data_processors/dpp3.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_39.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/explanations_shap/out.csv/._SUCCESS.crc'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_37.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_21.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_18.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_72.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_78.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_73.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_1.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_49.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_26.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_1.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_58.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_75.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_28.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/candidate_data_processors/dpp2.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_5.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_22.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_64.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/data-processor-models/automl-banking-13-03-39-12-dpp1-1-a1a25774a06e4c7eb05cec83bdfeb/output/model.tar.gz'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_53.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/report.ipynb'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_32.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_16.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_14.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/config.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_0.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_10.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_0.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/common.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_59.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_56.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/explanations_shap/out.csv/.part-00000-6f340e75-c8b1-4a69-8729-a76d8b6ae097-c000.csv.crc'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/validations/output_validation'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_45.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_5.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/explainability_samples/sample.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_74.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_76.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_68.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/setup.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_38.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_24.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_8.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_10.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_29.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_77.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_62.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/explanations_shap/out.csv/part-00000-6f340e75-c8b1-4a69-8729-a76d8b6ae097-c000.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_19.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_15.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/tuning/automl-ban-dpp3-xgb/automl-banking-13-03-39-12PjvDdi-002-91ec2a21/output/model.tar.gz'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/data-processor-models/automl-banking-13-03-39-12-dpp2-1-3c6cf48f1fab49a2a667d3a985db5/output/model.tar.gz'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_16.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_19.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_70.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/generated_module/README.md'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_11.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_5.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_42.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/sagemaker_automl/steps.py'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/tuning/automl-ban-dpp3-xgb/automl-banking-13-03-39-12PjvDdi-001-90f87382/output/model.tar.gz'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_2.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_36.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_71.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_55.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/data-processor-models/automl-banking-13-03-39-12-dpp3-1-34d68a88b2634f1e927ea2169afce/output/model.tar.gz'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_13.csv.out'},
# ...
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_25.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/sagemaker-automl-candidates/automl-banking-13-03-39-12-pr-1-83a29d3900324a9bb0519d367aa34c9/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_34.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_7.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_13.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_52.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_1.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_0.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_15.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_6.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_20.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_4.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_67.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_27.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_5.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_5.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_18.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_40.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_33.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_11.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_16.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_51.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_13.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_8.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/documentation/explainability/output/automl-banking-13-03-39-12PjvDdi-001-90f87382/explanations_shap/baseline.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_7.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/header/headers.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/validation/chunk_3.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/preprocessed-data/tuning_data/train/chunk_14.csv'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_15.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp3/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp1/csv/train/chunk_17.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp2/rpb/train/chunk_9.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp0/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/autopilot-dm/output/automl-banking-13-03-39-12/transformed-data/dpp4/rpb/validation/chunk_5.csv.out'}]}]
